# %%
import pickle

# %%
train_X = pickle.load(open("train_X.pkl", "rb"))
train_X
# Out:
# [[54.8598,
#   33.0166,
#   9999.0,
#   9999.1,
#   8.9676,
#   -33.5934,
#   -63.2506,
#   9999.2,
#   9999.3,
#   9999.4,
#   9999.5,
#   32.1051,
#   14.5333,
#   9999.6,
#   9999.7,
#   -30.5872,
#   -57.6515,
#   41.6003,
#   9999.8,
#   9999.9,
#   9999.1,
#   9999.11],
#  [9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0],
#  [-87.4883,
#   -38.9467,
#   32.8427,
#   93.5923,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9.1664,
#   -5.411,
#   0.091912,
#   -3.8473,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0],
#  [-140.2714,
#   -107.9045,
#   9999.0,
#   9999.0,
#   9999.0,
#   9999.0,
#   -23.9042,
#   65.4627,
#   76.341,
#   56.3595,
#   73.917,
#   -8.8671,
#   -25.8142,
#   9999.0,
# ...
